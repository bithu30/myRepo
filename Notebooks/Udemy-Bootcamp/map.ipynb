# %%
def farenheit(T):
    return ( 9.0/5) * T + 32

# %%
temp=[0,22.5,40,100]

# %%
map(farenheit,temp)
# Out:
# [32.0, 72.5, 104.0, 212.0]

# %%
map ( lambda T: ( 9.0/5) * T + 32,temp )
# Out:
# [32.0, 72.5, 104.0, 212.0]

# %%
a = [1,2,3]
b = [4,5,6]
c=  [7,8,9]

# %%
map(lambda x,y,z:x+y+z,a,b,c)
# Out:
# [12, 15, 18]

# %%
map(lambda num : num * -1,a)
# Out:
# [-1, -2, -3]
