# %%
# %matplotlib inline
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-3db670d570f0> in <module>()
# ----> 1 get_ipython().magic('matplotlib inline')
#       2 import sys
#       3 import numpy as np
#       4 import pandas as pd
#       5 import matplotlib.pyplot as plt
#
# C:\Anaconda2\envs\py35\lib\site-packages\IPython\core\interactiveshell.py in magic(self, arg_s)
#    2144         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2145         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2146         return self.run_line_magic(magic_name, magic_arg_s)
#    2147
#    2148     #-------------------------------------------------------------------------
#
# C:\Anaconda2\envs\py35\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line)
#    2065                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2066             with self.builtin_trap:
# -> 2067                 result = fn(*args,**kwargs)
#    2068             return result
#    2069
#
# <decorator-gen-105> in matplotlib(self, line)
#
# C:\Anaconda2\envs\py35\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# C:\Anaconda2\envs\py35\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# C:\Anaconda2\envs\py35\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    2921         """
#    2922         from IPython.core import pylabtools as pt
# -> 2923         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    2924
#    2925         if gui != 'inline':
#
# C:\Anaconda2\envs\py35\lib\site-packages\IPython\core\pylabtools.py in find_gui_and_backend(gui, gui_select)
#     258     """
#     259
# --> 260     import matplotlib
#     261
#     262     if gui and gui != 'auto':
#
# ImportError: No module named 'matplotlib'

# %%
# Dataset: https://archive.ics.uci.edu/ml/datasets/Iris/
# IRIS Dataset Size: 150 samples
# Train: 70%  Eval: 30%

# %%
data_path = r'C:\AWSMLCourse\Data\ClassExamples\Iris'

# %%
df = pd.read_csv(os.path.join(data_path,'iris.data.csv'))

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
# Print first 5 index values and last 5 index values
index_list = list(df.index)
print(index_list[:5])
print(index_list[-5:])
# Out:
# [0, 1, 2, 3, 4]
# [145, 146, 147, 148, 149]

# %%
# Randomize a list
np.random.seed(5)
np.random.shuffle(index_list)

# %%
print('Shuffled list')
print(index_list[:5])
print(index_list[-5:])
# Out:
# Shuffled list
# [82, 134, 114, 42, 109]
# [8, 73, 144, 118, 99]

# %%
# Dataframe is now shuffled
df = df.ix[index_list]

# %%
df.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 82            5.8          2.7           3.9          1.2  Iris-versicolor
# 134           6.1          2.6           5.6          1.4   Iris-virginica
# 114           5.8          2.8           5.1          2.4   Iris-virginica
# 42            4.4          3.2           1.3          0.2      Iris-setosa
# 109           7.2          3.6           6.1          2.5   Iris-virginica

# %%
df.to_csv(os.path.join(data_path,'iris_data_train.csv'),index=True,index_label='Row',
columns=['sepal_length','sepal_width','petal_length','petal_width','class'])

# %%
df.to_csv(os.path.join(data_path,'iris_data_classifier_test.csv'),index=True,index_label='Row',
          columns=['sepal_length','sepal_width','petal_length','petal_width'])

# %%
df['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Find all rows that match the condition.  Returns a Series that contains index value and True/False
setosa = df['class'] == 'Iris-setosa'

# %%
setosa.head()
# Out:
# 82     False
# 134    False
# 114    False
# 42      True
# 109    False
# Name: class, dtype: bool

# %%
# Pull only setosa's
df[setosa].head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 25           5.0          3.0           1.6          0.2  Iris-setosa
# 26           5.0          3.4           1.6          0.4  Iris-setosa
# 23           5.1          3.3           1.7          0.5  Iris-setosa

# %%
plt.hist(df.petal_length)
plt.grid(True)
plt.xlabel('Petal Length')
plt.ylabel('Count')
plt.title('Petal Length Histogram')

# %%
plt.scatter(df.index, df.petal_length)
plt.grid(True)
plt.xlabel('Sample')
plt.ylabel('Petal Length')
plt.title('Petal Length Scatter Plot')
