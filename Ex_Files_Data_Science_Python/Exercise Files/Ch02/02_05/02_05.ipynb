# %% [markdown]
# # Learning Jupyter Notebook

# %%
40 + 2
# Out:
# 42

# %%
import numpy as np

# %%
np.sin(90)
# Out:
# 0.89399666360055785

# %%
np.sin?

# %%
np.any??

# %%
# %pwd
# Out:
# '/Users/mikitebeka'

# %%
# %%time
for i in range(5):
    print(np.sin(5))
# Out:
# -0.958924274663
# -0.958924274663
# -0.958924274663
# -0.958924274663
# -0.958924274663
# CPU times: user 694 µs, sys: 854 µs, total: 1.55 ms
# Wall time: 937 µs

# %%
# %magic

# %%
# !ls /var/log
# Out:
# Bluetooth                 com.apple.clouddocs.asl   system.log.0.gz
# CDIS.custom               com.apple.revisiond       system.log.1.gz
# DiagnosticMessages        com.apple.xpc.launchd     system.log.2.gz
# accountpolicy.log         commerce.log              system.log.3.gz
# accountpolicy.log.0.gz    cups                      system.log.4.gz
# accountpolicy.log.1.gz    daily.out                 system.log.5.gz
# accountpolicy.log.2.gz    displaypolicyd.log        system.log.6.gz
# accountpolicy.log.3.gz    displaypolicyd.stdout.log system.log.7.gz
# accountpolicy.log.4.gz    emond                     timezone
# accountpolicy.log.5.gz    fax                       uucp
# accountpolicy.log.6.gz    fsck_hfs.log              weekly.out
# accountpolicy.log.7.gz    install.log               wifi.log
# apache2                   jamf.log                  wifi.log.0.bz2
# asl                       module                    wifi.log.1.bz2
# authd.log                 monthly.out               wifi.log.10.bz2
# authd.log.0.gz            opendirectoryd.log        wifi.log.2.bz2
# authd.log.1.gz            opendirectoryd.log.0      wifi.log.3.bz2
# authd.log.2.gz            opendirectoryd.log.1      wifi.log.4.bz2
# authd.log.3.gz            opendirectoryd.log.2      wifi.log.5.bz2
# authd.log.4.gz            powermanagement           wifi.log.6.bz2
# authd.log.5.gz            ppp                       wifi.log.7.bz2
# authd.log.6.gz            sa                        wifi.log.8.bz2
# authd.log.7.gz            secinitd.log.0.gz         wifi.log.9.bz2
# booth_enroll.log          snmpd.log
# booth_post.log            system.log

# %%
dir_name = '/var/log'
# !ls $dir_name
# Out:
# Bluetooth                 com.apple.clouddocs.asl   system.log.0.gz
# CDIS.custom               com.apple.revisiond       system.log.1.gz
# DiagnosticMessages        com.apple.xpc.launchd     system.log.2.gz
# accountpolicy.log         commerce.log              system.log.3.gz
# accountpolicy.log.0.gz    cups                      system.log.4.gz
# accountpolicy.log.1.gz    daily.out                 system.log.5.gz
# accountpolicy.log.2.gz    displaypolicyd.log        system.log.6.gz
# accountpolicy.log.3.gz    displaypolicyd.stdout.log system.log.7.gz
# accountpolicy.log.4.gz    emond                     timezone
# accountpolicy.log.5.gz    fax                       uucp
# accountpolicy.log.6.gz    fsck_hfs.log              weekly.out
# accountpolicy.log.7.gz    install.log               wifi.log
# apache2                   jamf.log                  wifi.log.0.bz2
# asl                       module                    wifi.log.1.bz2
# authd.log                 monthly.out               wifi.log.10.bz2
# authd.log.0.gz            opendirectoryd.log        wifi.log.2.bz2
# authd.log.1.gz            opendirectoryd.log.0      wifi.log.3.bz2
# authd.log.2.gz            opendirectoryd.log.1      wifi.log.4.bz2
# authd.log.3.gz            opendirectoryd.log.2      wifi.log.5.bz2
# authd.log.4.gz            powermanagement           wifi.log.6.bz2
# authd.log.5.gz            ppp                       wifi.log.7.bz2
# authd.log.6.gz            sa                        wifi.log.8.bz2
# authd.log.7.gz            secinitd.log.0.gz         wifi.log.9.bz2
# booth_enroll.log          snmpd.log
# booth_post.log            system.log

# %%
files = !ls /var/log
print('We have {} files at {}'.format(len(files), dir_name))
# Out:
# We have 73 files at /var/log

# %% [markdown]
# Some text goes here
#
# * list
# * of
# * item
#
# # Head 1
#
# ## Head 2
#
# [Pandas](http://pandas.pydata.org) is awesome.
#
# ![](https://static.pexels.com/photos/54632/cat-animal-eyes-grey-54632.jpeg)
#
# Euler's identity is $e^{i\pi}+1=0$

# %%
dir_name
# Out:
# '/var/log'

# %%
y = x + 7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-473729dcd804> in <module>()
# ----> 1 y = x + 7
#
# NameError: name 'x' is not defined

# %%
y
