# %%
# %matplotlib notebook

# %%
import pandas as pd
df = pd.read_csv('lnkd.csv', parse_dates=['Date'], index_col='Date')
df[['Close', 'Volume']].plot(subplots=True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1122478d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x114808780>], dtype=object)
