# %%
import tensorflow as tf
# Out:
# /home/bijith/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
hello = tf.constant("hello world")

# %%
sess = tf.Session()

# %%
print(sess.run(hello))
# Out:
# b'hello world'
